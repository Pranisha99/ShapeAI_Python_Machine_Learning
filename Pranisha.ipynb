# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/Administrator/Downloads/excel-spreadsheet-examples-for-students.csv')

df.head()
# Out:
#   First Name Last Name                Company Name                Address  \
# 0   Rebbecca     Didio      Brandt, Jonathan F Esq          171 E 24th St
# 1     Stevie     Hallo  Landrum Temporary Services         22222 Acoma St
# 2     Mariko    Stayer         Inabinet, Macre Esq  534 Schoenborn St #51
# 3    Gerardo    Woodka    Morris Downing & Sherred      69206 Jackson Ave
# 4      Mayra      Bena          Buelt, David L Esq      808 Glen Cove Ave
#
#         City State      Phone No                        Email  \
# 0      Leith   TAS  03-8174-9123  rebbecca.didio@didio.com.au
# 1    Proston   QLD  07-9997-3366     stevie.hallo@hotmail.com
# 2      Hamel    WA  08-5558-9019    mariko_stayer@hotmail.com
# 3   Talmalmo   NSW  02-6044-4682   gerardo_woodka@hotmail.com
# 4  Lane Cove   NSW  02-1455-6085         mayra.bena@gmail.com
#
#                                           Web
# 0        http://www.brandtjonathanfesq.com.au
# 1  http://www.landrumtemporaryservices.com.au
# ...

# %%
df.describe(include='all')
# Out:
#        First Name Last Name  Company Name        Address           City State  \
# count         500       500           500            500            500   500
# unique        484       500           498            500            480     8
# top        Gerald     Didio  House Of Ing  171 E 24th St  Varsity Lakes   NSW
# freq            2         1             2              1              2   125
#
#             Phone No                        Email  \
# count            500                          500
# unique           500                          500
# top     03-8174-9123  rebbecca.didio@didio.com.au
# freq               1                            1
#
#                                  Web
# count                            500
# unique                           498
# top     http://www.houseofing.com.au
# freq                               2

# %%
df.rename(columns = {'Address':'Location'}, inplace = True)

# %%
df.head()
# Out:
#   First Name Last Name                Company Name               Location  \
# 0   Rebbecca     Didio      Brandt, Jonathan F Esq          171 E 24th St
# 1     Stevie     Hallo  Landrum Temporary Services         22222 Acoma St
# 2     Mariko    Stayer         Inabinet, Macre Esq  534 Schoenborn St #51
# 3    Gerardo    Woodka    Morris Downing & Sherred      69206 Jackson Ave
# 4      Mayra      Bena          Buelt, David L Esq      808 Glen Cove Ave
#
#         City      Phone No                        Email
# 0      Leith  03-8174-9123  rebbecca.didio@didio.com.au
# 1    Proston  07-9997-3366     stevie.hallo@hotmail.com
# 2      Hamel  08-5558-9019    mariko_stayer@hotmail.com
# 3   Talmalmo  02-6044-4682   gerardo_woodka@hotmail.com
# 4  Lane Cove  02-1455-6085         mayra.bena@gmail.com

# %%
df.drop(['Location'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   First Name Last Name                Company Name       City      Phone No  \
# 0   Rebbecca     Didio      Brandt, Jonathan F Esq      Leith  03-8174-9123
# 1     Stevie     Hallo  Landrum Temporary Services    Proston  07-9997-3366
# 2     Mariko    Stayer         Inabinet, Macre Esq      Hamel  08-5558-9019
# 3    Gerardo    Woodka    Morris Downing & Sherred   Talmalmo  02-6044-4682
# 4      Mayra      Bena          Buelt, David L Esq  Lane Cove  02-1455-6085
#
#                          Email
# 0  rebbecca.didio@didio.com.au
# 1     stevie.hallo@hotmail.com
# 2    mariko_stayer@hotmail.com
# 3   gerardo_woodka@hotmail.com
# 4         mayra.bena@gmail.com

# %%
print(df.City)
# Out:
# 0           Leith
# 1         Proston
# 2           Hamel
# 3        Talmalmo
# 4       Lane Cove
#           ...
# 495     Barringun
# 496       Pilliga
# 497        Rhodes
# 498    Castletown
# 499        Turill
# Name: City, Length: 500, dtype: object
